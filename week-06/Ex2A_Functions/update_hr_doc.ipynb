# %%
hr_list = [
    ('0123', 'HR', 'Rebecca Yang', '69000'),
    ('0121', 'IT', 'Mark Blick', '67000'),
    ('0068', 'IT', 'Kahna Larsen', '112000'),
    ('0234', 'OPS', 'Jim Smith', '54000')
]

# %%
# Find and update Mark
for i, emp in enumerate(hr_list):
    if emp[2] == 'Mark Blick':
        hr_list[i] = (emp[0], emp[1], 'Mark Blick-Hawley', emp[3])
        break
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'OPS', 'Jim Smith', '54000')]

# %%
for i, emp in enumerate(hr_list):
    if emp[2].startswith('Jim'):
        hr_list[i] = (emp[0], 'CS', emp[2], '60000')
        break
print(hr_list)
# Out:
# [('0123', 'HR', 'Rebecca Yang', '69000'), ('0121', 'IT', 'Mark Blick-Hawley', '67000'), ('0068', 'IT', 'Kahna Larsen', '112000'), ('0234', 'CS', 'Jim Smith', '60000')]

# %%
for emp in hr_list:
    emp_num, dept, name, salary = emp
    print(f"Employee# | DeptCode | Name | ${int(salary):,}")
# Out:
# Employee# | DeptCode | Name | $69,000
# Employee# | DeptCode | Name | $67,000
# Employee# | DeptCode | Name | $112,000
# Employee# | DeptCode | Name | $60,000
