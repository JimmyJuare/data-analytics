# %% [markdown]
# # Exercise 2.A Using built-in functions
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    first = ''
    last = ''
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]
            break
    print(f"Full name: {name}")
    print(f"First name: {first}")
    print(f"Last name: {last}")

# use the existing variable
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']
for name in test_list:
    parse_and_display(name)
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen
# Full name: Ken Penn
# First name: Ken
# Last name: Penn

# %%
parse_and_display('Jimmy Juarez')
# Out:
# Full name: Jimmy Juarez
# First name: Jimmy
# Last name: Juarez

# %%
def parse_and_display2(name):
    parts = name.split()
    
    first = parts[0] if len(parts) > 0 else ''
    middle = parts[1] if len(parts) > 2 else ''
    last = parts[-1] if len(parts) > 1 else ''
    
    print(f"Full name: {name}")
    print(f"First name: {first}")
    if middle:
        print(f"Middle name: {middle}")
    print(f"Last name: {last}")
    print()

# Test with the example names
parse_and_display2('Lorde')
parse_and_display2('Billie Eilish')
parse_and_display2('Megan Thee Stallion')
# Out:
# Full name: Lorde
# First name: Lorde
# Last name:
#
# Full name: Billie Eilish
# First name: Billie
# Last name: Eilish
#
# Full name: Megan Thee Stallion
# First name: Megan
# Middle name: Thee
# Last name: Stallion
