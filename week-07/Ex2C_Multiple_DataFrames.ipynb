# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Aggregations

# %%
data = {
    'Product': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North'],
    'Units_Sold': [10, 15, 20, 5, 10, 15, 10, 5, 15],
    'Price': [100, 200, 150, 100, 200, 150, 100, 200, 150]
}

df_sales = pd.DataFrame(data)
df_sales['Revenue'] = df_sales['Units_Sold'] * df_sales['Price']

print("Total Units Sold:", df_sales['Units_Sold'].sum())
print("Total Revenue:", df_sales['Revenue'].sum())
print("Average Units Sold:", df_sales['Units_Sold'].mean())

# %% [markdown]
# ## Grouping Data

# %%
print(df_sales.groupby('Product')[['Units_Sold', 'Revenue']].sum())
print(df_sales.groupby('Region')[['Units_Sold', 'Revenue']].mean())
print(df_sales.groupby(['Product', 'Region'])[['Units_Sold', 'Revenue']].sum())

# %% [markdown]
# ## Sorting and Ranking Data

# %%
print(df_sales.sort_values('Units_Sold'))
print(df_sales.sort_values('Revenue', ascending=False))

df_sales['Revenue_Rank'] = df_sales['Revenue'].rank(ascending=False)
print(df_sales)

# %% [markdown]
# ## Merging DataFrames

# %%
product_data = {
    'Product': ['A', 'B', 'C'],
    'Category': ['Electronics', 'Furniture', 'Appliances']
}
df_products = pd.DataFrame(product_data)

df_merged = pd.merge(df_sales, df_products, on='Product')
print(df_merged)

print(df_merged.groupby('Category')['Revenue'].sum())
